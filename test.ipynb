# %% [markdown]
# # OneClickML

# %% [markdown]
# ### This is a test working of OneClickML, We will try it on 1) Regression Dataset & on 2) Classification Dataset

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from oneclickml import ModelTraining

# %% [markdown]
# ### Regression Dataset

# %%
data = pd.read_csv("/Users/karnavivek/OneClickML/Dataset/WFP_dataset.csv")
X = data.drop('label', axis=1)
y = data.label
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

seed = 17

#for running ALL models in a single iteration:
model_list = ['linear','DT','MLP','GBM','RF','SVM']

#for running single model in a single iteration
# model_list = ['linear']

all_results = []

for alg in model_list:
    model = ModelTraining(X, y)
    perf = model.run_models(X_train, y_train, alg, seed=seed, X_test=X_test, y_test=y_test, binary=False)
    all_results.append(perf)

results_df = pd.DataFrame(all_results)
print("\nModel Performance Summary:\n")
print(results_df)

if results_df['Model'][0]=='Linear Regression':
    print(f'\nOneClickML Recommeds "{results_df.loc[results_df['MSE Score'].idxmin(), 'Model']}" Model with Minimum score: {min(results_df['MSE Score'])}')
else:
    print(f'\nOneClickML Recommeds "{results_df.loc[results_df['ROC Score'].idxmin(), 'Model']}" Model with Minimum score: {min(results_df['ROC Score'])}')
# Out:
# Running 'Linear Regression' Model | Metric: 'MSE' ...
#
# Training...
#
# Your Linear Regression model has been trained!
#
# -------------------------------------------------------
#
# Running 'DT Regressor' Model | Metric: 'MSE' ...
#
# Training...
#
# Your Decision Tree Regressor model has been trained!
#
# -------------------------------------------------------
#
# Running 'MLP Regressor' Model | Metric: 'MSE' ...
#
# Training...
#
# Your MLP Regressor model has been trained!
#
# -------------------------------------------------------
#
# Running 'GBM Regression' Model | Metric: 'MSE' ...
#
# Training...
#
# Your GBM Regressor model has been trained!
#
# -------------------------------------------------------
#
# Running 'RF Regression' Model | Metric: 'MSE' ...
#
# Training...
#
# Your RF Regressor model has been trained!
#
# -------------------------------------------------------
#
# Running 'SVM Regression' Model | Metric: 'MSE' ...
#
# Training...
#
# Your SVM Regressor model has been trained!
#
# -------------------------------------------------------
#
# Model Performance Summary:
#
#                       Model  ...                                        Best Params
# 0         Linear Regression  ...  {'fit_intercept': True, 'n_jobs': 1, 'positive...
# 1  Decision Tree Regression  ...  {'max_depth': 10, 'max_features': 1.0, 'min_sa...
# 2            MLP Regression  ...                     {'hidden_layer_sizes': (100,)}
# 3            GBM Regression  ...  {'learning_rate': 0.2, 'max_depth': 5, 'n_esti...
# 4             RF Regression  ...               {'max_depth': 4, 'n_estimators': 10}
# 5            SVM Regression  ...                                         {'C': 100}
#
# [6 rows x 5 columns]
#
# OneClickML Recommeds "GBM Regression" Model with Minimum score: 0.006074557705066906

# %%
results_df
# Out:
#                       Model  ...                                        Best Params
# 0         Linear Regression  ...  {'fit_intercept': True, 'n_jobs': 1, 'positive...
# 1  Decision Tree Regression  ...  {'max_depth': 10, 'max_features': 1.0, 'min_sa...
# 2            MLP Regression  ...                     {'hidden_layer_sizes': (100,)}
# 3            GBM Regression  ...  {'learning_rate': 0.2, 'max_depth': 5, 'n_esti...
# 4             RF Regression  ...               {'max_depth': 4, 'n_estimators': 10}
# 5            SVM Regression  ...                                         {'C': 100}
#
# [6 rows x 5 columns]

# %% [markdown]
# ### Classification Dataset

# %%
data = pd.read_csv("/Users/karnavivek/OneClickML/Dataset/happydata.csv")
data
# Out:
#      infoavail  housecost  schoolquality  ...  streetquality  ëvents  happy
# 0            3          3              3  ...              2       4      0
# 1            3          2              3  ...              4       3      0
# 2            5          3              3  ...              3       5      1
# 3            5          4              3  ...              3       5      0
# 4            5          4              3  ...              3       5      0
# ..         ...        ...            ...  ...            ...     ...    ...
# 138          5          3              3  ...              3       5      0
# 139          5          2              3  ...              2       5      1
# 140          5          3              3  ...              4       5      1
# 141          4          3              3  ...              4       5      0
# 142          5          3              2  ...              5       5      0
#
# [143 rows x 7 columns]

# %%
y = data.happy
X = data.drop("happy",axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
seed = 18

#for running ALL models in a single iteration:
model_list = ['linear','DT','MLP','GBM','RF','SVM']

#for running single model in a single iteration
# model_list = ['linear']

all_results = []

for alg in model_list:
    model = ModelTraining(X, y)
    perf = model.run_models(X_train, y_train, alg, seed=seed, X_test=X_test, y_test=y_test, binary=True)
    all_results.append(perf)

results_df = pd.DataFrame(all_results)
print("\nModel Performance Summary:\n")
print(results_df)

if results_df['Model'][0]=='Linear Regression':
    print(f'\nOneClickML Recommeds "{results_df.loc[results_df['MSE Score'].idxmin(), 'Model']}" Model with Minimum score: {min(results_df['MSE Score'])}')
else:
    print(f'\nOneClickML Recommeds "{results_df.loc[results_df['ROC Score'].idxmin(), 'Model']}" Model with Minimum score: {min(results_df['ROC Score'])}')
# Out:
# Running 'Logistic Regression' Model | Metric: 'ROC_AUC' ...
#
#
# Training...
#
# Your Logistic Regression model has been trained!
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 100 fits failed out of a total of 200.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 100 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py", line 1193, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py", line 63, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1107: UserWarning: One or more of the test scores are non-finite: [0.54268775        nan 0.56047431        nan 0.59565217        nan
#  0.59565217        nan 0.60474308        nan 0.60474308        nan
#  0.60474308        nan 0.60434783        nan 0.60434783        nan
#  0.60434783        nan 0.60434783        nan 0.60434783        nan
#  0.61304348        nan 0.61304348        nan 0.62173913        nan
#  0.62173913        nan 0.62173913        nan 0.62173913        nan
#  0.62173913        nan 0.61304348        nan]
#   warnings.warn(
# -------------------------------------------------------
# Running 'DT Classifier' Model | Metric: 'ROC_AUC' ...
# Training...
#
# Your Decision Tree Classifier model has been trained!
#
# -------------------------------------------------------
#
# Running 'MLP Classifier' Model | Metric: 'ROC_AUC' ...
#
# Training...
#
# Your MLP Classifier model has been trained!
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# -------------------------------------------------------
#
# Running 'GBM Classifier' Model | Metric: 'ROC_AUC' ...
#
# Training...
#
# Your GBM Classifier model has been trained!
#
# -------------------------------------------------------
#
# Running 'RF Classifier' Model | Metric: 'ROC_AUC' ...
#
# Training...
#
# Your RF Classifier model has been trained!
#
# -------------------------------------------------------
#
# Running 'SVM Classification' Model | Metric: 'ROC_AUC' ...
#
# Training...
#
# Your SVM Classifier model has been trained!
#
# -------------------------------------------------------
#
# Model Performance Summary:
#
#                       Model  ...                                        Best Params
# 0       Logistic Regression  ...         {'C': 0.7010000000000001, 'penalty': 'l2'}
# 1  Decision Tree Classifier  ...  {'max_depth': 3, 'max_features': 0.6, 'min_sam...
# 2            MLP Classifier  ...                      {'hidden_layer_sizes': (20,)}
# 3            GBM Regression  ...  {'learning_rate': 0.01, 'max_depth': 3, 'n_est...
# 4             RF Classifier  ...                {'max_depth': 3, 'n_estimators': 5}
# 5            SVM Classifier  ...                                           {'C': 1}
#
# [6 rows x 5 columns]
#
# OneClickML Recommeds "MLP Classifier" Model with Minimum score: 0.4666666666666667

# %%
results_df
# Out:
#                       Model  ...                                        Best Params
# 0       Logistic Regression  ...         {'C': 0.7010000000000001, 'penalty': 'l2'}
# 1  Decision Tree Classifier  ...  {'max_depth': 3, 'max_features': 0.6, 'min_sam...
# 2            MLP Classifier  ...                      {'hidden_layer_sizes': (20,)}
# 3            GBM Regression  ...  {'learning_rate': 0.01, 'max_depth': 3, 'n_est...
# 4             RF Classifier  ...                {'max_depth': 3, 'n_estimators': 5}
# 5            SVM Classifier  ...                                           {'C': 1}
#
# [6 rows x 5 columns]
